# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
val = [0.796, 0.806, 0.806, 0.812, 0.812, 0.812, 0.812, 0.812, 0.812, 0.818, 0.818, 0.808, 0.808, 0.812, 0.814, 0.808, 0.812, 0.812, 0.812, 0.812, 0.816, 0.816, 0.818, 0.81, 0.81, 0.824, 0.824, 0.824, 0.824, 0.824, 0.824, 0.822, 0.812, 0.83, 0.83, 0.83, 0.83, 0.826, 0.826, 0.826, 0.826, 0.826, 0.826, 0.826, 0.826, 0.826, 0.826, 0.81, 0.81, 0.81]
test = [0.804, 0.785, 0.785, 0.809, 0.809, 0.809, 0.809, 0.809, 0.809, 0.808, 0.808, 0.822, 0.793, 0.82, 0.818, 0.805, 0.802, 0.802, 0.802, 0.802, 0.818, 0.818, 0.829, 0.816, 0.816, 0.829, 0.829, 0.829, 0.829, 0.829, 0.829, 0.825, 0.807, 0.844, 0.844, 0.844, 0.844, 0.832, 0.832, 0.832, 0.832, 0.832, 0.832, 0.832, 0.832, 0.832, 0.832, 0.816, 0.816, 0.828]

argmax = np.argmax(test)
print(argmax)
print(test[argmax])
# Out:
# 33
# 0.844

# %%
def result_plot(val, test, title):
    plt.clf() 
    plt.figure(figsize=(15, 5))

    epochs = range(len(val))

    plt.plot(epochs, val, label='val', marker='o')
    plt.plot(epochs, test, label='test', marker='o')
    plt.xlabel('Generations')
    plt.ylabel('Accuracy')
    
    #plt.title(title)
    plt.legend()

    plt.show()

result_plot(val, test, 'Accuracy')
